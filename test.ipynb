# %%
import akshare as ak


df = ak.stock_zh_a_spot_em()
df = df[['代码', '名称', '最新价']]
df = df.rename(columns={'代码': '证券代码',
                        '名称': '证券名称'})
df
# Out:
#         证券代码   证券名称    最新价
# 0     836149   旭杰科技   9.76
# 1     300989   蕾奥规划  22.09
# 2     831152   昆工科技  19.23
# 3     870204   沪江材料  16.72
# 4     600825   新华传媒   5.13
# ...      ...    ...    ...
# 5574  603595   东尼电子  31.44
# 5575  603004   鼎龙科技  34.12
# 5576  603097   江苏华辰  24.82
# 5577  603665    康隆达  24.44
# 5578  300799  *ST左江  26.65
#
# [5579 rows x 3 columns]

# %%
# 000338
p = ak.stock_zh_a_hist('000338', 'daily', '20240108')
p
# Out:
#            日期     开盘    收盘     最高     最低     成交量           成交额    振幅   涨跌幅  \
# 0  2024-01-08  14.24  14.0  14.35  13.98  199290  2.822807e+08  2.61 -1.06
#
#     涨跌额  换手率
# 0 -0.15  0.4
